# %%
# 1월 구간 수익률
RP1 = -0.0517
# 2월 구간 수익률
RP2 = 0.0228
# 3월 구간 수익률
RP3 = 0.0239

#24년 포트폴리오 시간 가중 수익률
TWR = (1+RP1)*(1+RP2)*(1+RP3)-1
print("2024.01.01 ~ 2024.03.31 시간 가중 수익률: {:.4f}%".format(TWR))
# Out:
# 2024.01.01 ~ 2024.03.31 시간 가중 수익률: -0.0069%

# %% [markdown]
# ![image.png](attachment:image.png)
